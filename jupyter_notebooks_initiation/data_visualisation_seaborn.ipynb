# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Seaborn :** package au-dessus de matplotlib (nécessite matplotlib) qui offre des fonctionnalités de plus haut niveau. Seaborn remplace certains réglages par défaut et fonctions, et ajoute de nouvelles fonctionnalités. Le package s'interface avec les DataFrame de pandas.

# %%
#matplotlib 
x = np.linspace(0, 10, 500)
y = np.random.randn(500)
plt.plot(x,y)

# %%
#seaborn 

sns.set()

x = np.linspace(0, 10, 500)
y = np.random.randn(500)
plt.plot(x,y)

# %%
df = sns.load_dataset('iris')

# %% [markdown]
# ##### Description du jeu de données :
# Le jeu de données Iris comprend 50 échantillons de chacune des trois espèces des fleurs Iris (Iris setosa, Iris virginica et Iris versicolor).  Quatre caractéristiques ont été mesurées à partir de chaque échantillon : la longueur et la largeur des sépales et des pétales, en centimètres.
#
# <span style='color:red'> Le jeu de données Iris connu aussi sous le nom de Iris de Fisher est un jeu de données multivariées présenté en 1936 par Ronald Fisher dans son papier The use of multiple measurements in taxonomic problems comme un exemple d'application de l'analyse discriminante linéaire </span>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Visualisation des variables quantitatives continues

# %%
sns.distplot(df['petal_length'])
plt.show()

# %%
sns.distplot(df['petal_length'],kde = False)
plt.show()

# %% [markdown]
# Pour information kde(Kernel Density Estimation) est l'estimation de la fonction de densité de probabilité d'une variable aléatoire continues (Rvoir cours sur les lois de probabilité)

# %%
sns.distplot(df['petal_length'],hist = False)
plt.show()

# %% [markdown]
# ### Visualisation bi-variée

# %% [markdown]
# Durant la phase d'exploration des données, il est nécessaire de comprendre les relations entre les variables 2 à 2. La fonction pairplot() de seaborn nous permet d'observer les comportements des pairs de variables pour peut être dégager des tendances ou des intuitions pour nos modèles de machine learning

# %%
sns.set_style("ticks")
sns.pairplot(df, hue='species', kind = "scatter",palette = "husl")
plt.show()

# %%
sns.boxplot(data=df)

# %%
corr = df.corr()

# %%
sns.heatmap(corr)

# %% [markdown]
# ### Visualisation de variables catégorielles

# %% [markdown]
# In our previous chapters we learnt about scatter plots, hexbin plots and kde plots which are used to analyze the continuous variables under study. These plots are not suitable when the variable under study is categorical.
#
# When one or both the variables under study are categorical, we use plots like striplot(), swarmplot(), etc,. Seaborn provides interface to do so

# %%
# stripplot() is used when one of the variable under study is categorical

sns.stripplot(x = "species", y = "petal_length", data = df)
plt.show()

# %%
sns.countplot(x = "species",data=df, palette="Reds")
