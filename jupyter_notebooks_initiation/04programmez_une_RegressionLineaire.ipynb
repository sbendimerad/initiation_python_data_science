# %%
# import packages
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# import dataset
house_data = pd.read_csv("./data/house.csv")

# %%
house_data.head()
# Out:
#    loyer  surface
# 0   1330       37
# 1   1400       32
# 2    904       26
# 3    955       30
# 4   2545       70

# %%
# On affiche le nuage de points dont on dispose
plt.plot(house_data['surface'], house_data['loyer'], 'bo', markersize=4)

m, b = np.polyfit(house_data["surface"], house_data["loyer"],1)
plt.plot(house_data["surface"], m*house_data["surface"] + b,"r")

plt.title("Evolution des loyer par rapport à la surface")
plt.xlabel("surface")
plt.ylabel("loyer")
plt.show()

# %%
house_data = house_data[house_data['loyer'] < 10000]

# %%
# On décompose le dataset et on le transforme en matrices pour pouvoir effectuer notre calcul
X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['loyer']).T

# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

print(theta)
# Out:
# [[266.45460292]
#  [ 30.66119596]]

# %%
# On affiche le nuage de points dont on dispose
plt.plot(house_data['surface'], house_data['loyer'], 'bo', markersize=4)

# On affiche la droite entre 0 et 250
plt.plot(house_data['surface'], theta[1,0]*house_data['surface'] + theta[0,0],"r" )
 


plt.title("Evolution des loyer par rapport à la surface")
plt.xlabel("surface")
plt.ylabel("loyer")
plt.show()

# %%
# Utilise le modèle pour faire une prédiction (Par exemple pour une surface de 35)

theta[0,0]+theta[1,0]*35
# Out:
# 1339.5964615602245

# %% [markdown]
# On vient ici de décomposer l’entraînement de la régression linéaire. En réalité, vous vous doutez bien que cette régression est déjà implémentée dans le package scikit-learn. On peut l'utiliser directement de la manière suivante :

# %% [markdown]
# <div class="alert-success">
# from sklearn import linear_model <br>
# regr = linear_model.LinearRegression() <br>
# regr.fit(X, y) <br>
# regr.predict(<des données de test>) <br>
# </div>

# %% [markdown]
# Bonne nouvelle ! Les prochains modèles que nous utiliserons auront leurs algorithme d'entraînement et de prédiction directement implémentés dans scikit-learn, nous aurons juste à appeler directement leurs fonctions associées. 😎

# %%
help(linear_model.LinearRegression())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1523debb2c45> in <module>
# ----> 1 help(linear_model.LinearRegression())
#
# NameError: name 'linear_model' is not defined
